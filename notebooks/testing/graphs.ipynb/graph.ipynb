# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
df = px.data.tips()

categories = ['Pensions', 'General Insurance', 'Life Insurance', 'Finance & Investment', 'Other']
values = [49, 26, 16, 2, 7]
colors = ['plum', 'orchid', 'cornflowerblue', 'powderblue', 'skyblue']

text_labels = [f"{v}%" for v in values]

fig = go.Figure(
    data=[go.Pie(labels=categories, 
                 values=values,
                 text=text_labels, 
                 textinfo='text',
                 hovertemplate='%{label}: %{value}%',
                 insidetextorientation='auto', 
                 hole=0, 
                 marker=dict(colors=colors))]
)

fig.update_layout(
    title_text='Main Areas of Practice for Actuaries'
)

fig.show()

# %%
categories = ['Mathematics', 'Statistics', 'Economics/Finance/Business', 'Engineering', 'Physics', 'Computer Science', 'Data Science', 'Other']
values = [40, 15, 20, 8, 4, 7, 3, 3]
colors = ['plum', 'orchid', 'mediumpurple', 'cornflowerblue', 'skyblue', 'powderblue', 'paleturquoise', 'turquoise']

fig = go.Figure(
    data=[
        go.Bar(
            x=categories,
            y=values,
            text=values,
            textposition='outside',
            marker=dict(color=colors)
        )
    ]
)

fig.update_layout(
    title='Academic Backgrounds of Actuaries (Approximate)',
    xaxis_title='Background',
    yaxis_title='%',
    template='plotly_white',
    height=600
)

fig.show()
